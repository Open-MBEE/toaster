# %% [markdown]
# # Chapter 1 Exercise: System and Purpose
#
# Define an abstract part def for a coffee maker — same construct, different system.
#
# **Starting point:** Load `../../models/ch01-snapshot.sysml` (created when you complete the chapter notebooks).
#
# Use only constructs and operations introduced up to Chapter 1.
#
# Refer to the worked example in `../../chapters/ch01-*/` for reference.

# %%
# Your solution here
