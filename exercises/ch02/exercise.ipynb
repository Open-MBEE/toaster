# %% [markdown]
# # Chapter 2 Exercise: Requirements and Assumptions
#
# Add requirements and assumptions for the bread-handling subsystem.
#
# **Starting point:** Load `../../models/ch02-snapshot.sysml` (created when you complete the chapter notebooks).
#
# Use only constructs and operations introduced up to Chapter 2.
#
# Refer to the worked example in `../../chapters/ch02-*/` for reference.

# %%
# Your solution here
