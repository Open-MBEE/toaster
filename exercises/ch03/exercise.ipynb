# %% [markdown]
# # Chapter 3 Exercise: Measures of Success
#
# Define a MOP for heating cycle repeatability and evaluate two candidates.
#
# **Starting point:** Load `../../models/ch03-snapshot.sysml` (created when you complete the chapter notebooks).
#
# Use only constructs and operations introduced up to Chapter 3.
#
# Refer to the worked example in `../../chapters/ch03-*/` for reference.

# %%
# Your solution here
